# %%
! pip install streamlit
# Out:
# Requirement already satisfied: streamlit in d:\anaconda\lib\site-packages (1.21.0)
# Requirement already satisfied: gitpython!=3.1.19 in d:\anaconda\lib\site-packages (from streamlit) (3.1.31)
# Requirement already satisfied: python-dateutil in d:\anaconda\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: validators>=0.2 in d:\anaconda\lib\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: tornado>=6.0.3 in d:\anaconda\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: watchdog in d:\anaconda\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in d:\anaconda\lib\site-packages (from streamlit) (4.1.1)
# Requirement already satisfied: rich>=10.11.0 in d:\anaconda\lib\site-packages (from streamlit) (13.3.4)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from streamlit) (9.5.0)
# Requirement already satisfied: pandas<2,>=0.25 in d:\anaconda\lib\site-packages (from streamlit) (1.4.2)
# Requirement already satisfied: requests>=2.4 in c:\users\emam\appdata\roaming\python\python39\site-packages (from streamlit) (2.28.2)
# Requirement already satisfied: tzlocal>=1.1 in d:\anaconda\lib\site-packages (from streamlit) (4.3)
# Requirement already satisfied: blinker>=1.0.0 in d:\anaconda\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from streamlit) (1.22.4)
# Requirement already satisfied: pyarrow>=4.0 in d:\anaconda\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: altair<5,>=3.2.0 in d:\anaconda\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: packaging>=14.1 in d:\anaconda\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: cachetools>=4.0 in d:\anaconda\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: click>=7.0 in c:\users\emam\appdata\roaming\python\python39\site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: pympler>=0.9 in d:\anaconda\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: toml in d:\anaconda\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: protobuf<4,>=3.12 in d:\anaconda\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pydeck>=0.1.dev5 in d:\anaconda\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: importlib-metadata>=1.4 in d:\anaconda\lib\site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from altair<5,>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: entrypoints in d:\anaconda\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: toolz in d:\anaconda\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: jsonschema>=3.0 in d:\anaconda\lib\site-packages (from altair<5,>=3.2.0->streamlit) (4.4.0)
# Requirement already satisfied: colorama in c:\users\emam\appdata\roaming\python\python39\site-packages (from click>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\anaconda\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda\lib\site-packages (from packaging>=14.1->streamlit) (2.4.7)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas<2,>=0.25->streamlit) (2021.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.4->streamlit) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.4->streamlit) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->streamlit) (2.15.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: tzdata in d:\anaconda\lib\site-packages (from tzlocal>=1.1->streamlit) (2023.3)
# Requirement already satisfied: pytz-deprecation-shim in d:\anaconda\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in d:\anaconda\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from jinja2->altair<5,>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit) (0.1.2)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import Sequential
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy ,SparseCategoricalCrossentropy
from tensorflow.keras.activations import sigmoid
from tensorflow.keras.losses import MeanSquaredLogarithmicError
from tensorflow import keras as k
import numpy as np
# for building linear regression models and preparing data
from sklearn.linear_model import LinearRegression ,LogisticRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from xgboost import *
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
import cv2

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
#from keras.preprocessing.image import ImageDataGenerator, load_img
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras.applications import VGG16, InceptionResNetV2
from keras import regularizers
from keras.utils import plot_model
from keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
import datetime
labels={ 0:'angry',
 1:'disgust',
 2:'fear',
 3:'happy',
 4:'neutral',
 5:'sad',
6 :'surprise'}
colors={ 0:(0,0,255),
 1:(100,0,100),
 2:(200,50,123),
 3:(0,255,255),
 4:(0,255,0),
 5:(255,255,0),
6 :(255,0,0)}
import numpy as np
def reshape(img):
    img = cv2.resize(img, (48, 48))  # Resize to the input shape of the model
    print(img.shape)
    img = img.reshape( 1,48, 48, 1)
    return img

# %%
labels={ 0:'angry',
 1:'disgust',
 2:'fear',
 3:'happy',
 4:'neutral',
 5:'sad',
6 :'surprise'}
colors={ 0:(0,0,255),
 1:(100,0,100),
 2:(200,50,123),
 3:(0,255,255),
 4:(0,255,0),
 5:(255,255,0),
6 :(255,0,0)}

# %%
import numpy as np
def reshape(img):
    img = cv2.resize(img, (48, 48))  # Resize to the input shape of the model
    print(img.shape)
    img = img.reshape( 1,48, 48, 1)
    return img

# %%
from dlib import get_frontal_face_detector
import numpy as np
hog=get_frontal_face_detector()

model=k.models.load_model('fernet (1).h5')
vid=cv2.VideoCapture(0)# if you would put a vide revmove 0 and put the path
while True:
    rec,frame=vid.read() 
    print(rec)
    if (rec):
        img=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) 
        for block in hog(img,1,):
          print(block)
          if(img[block.top():block.bottom(),block.left():block.right()] !=[]):
            img=reshape(img[block.top():block.bottom(),block.left():block.right()])
            num=np.argmax(model.predict(img),axis=1)[0]
            mode=labels[num]
            cv2.rectangle(frame,(int(block.left()),int(block.top())),(int(block.right()),int(block.bottom())),colors[num],3)
            cv2.putText(frame,str(mode),(int(block.left()),int(block.top()-15)),cv2.FONT_ITALIC,1,colors[num],3)
        cv2.imshow("wind",frame)
        if (cv2.waitKey(1)==27):
            break
vid.release()
cv2.destroyAllWindows()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# [(369, 182) (405, 218)]
# (48, 48)
# C:\Users\Emam\AppData\Local\Temp\ipykernel_14276\516854339.py:14: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if(img[block.top():block.bottom(),block.left():block.right()] !=[]):
# 1/1 [==============================] - 0s 161ms/step
# True
# [(369, 182) (405, 218)]
# (48, 48)
# 1/1 [==============================] - 0s 49ms/step
# True
# [(369, 182) (405, 218)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(369, 182) (405, 218)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(369, 186) (405, 222)]
# (48, 48)
# 1/1 [==============================] - 0s 39ms/step
# True
# [(369, 186) (405, 222)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(369, 186) (405, 222)]
# (48, 48)
# 1/1 [==============================] - 0s 49ms/step
# True
# True
# [(365, 186) (401, 222)]
# (48, 48)
# 1/1 [==============================] - 0s 33ms/step
# True
# True
# True
# [(357, 175) (400, 218)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(357, 175) (400, 218)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(357, 175) (400, 218)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(357, 170) (400, 214)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(357, 170) (400, 214)]
# (48, 48)
# 1/1 [==============================] - 0s 34ms/step
# True
# True
# [(362, 170) (405, 214)]
# (48, 48)
# 1/1 [==============================] - 0s 48ms/step
# True
# [(362, 170) (405, 214)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(362, 170) (405, 214)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(362, 170) (405, 214)]
# (48, 48)
# 1/1 [==============================] - 0s 36ms/step
# True
# [(360, 170) (412, 222)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(362, 175) (405, 218)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(360, 176) (412, 228)]
# (48, 48)
# 1/1 [==============================] - 0s 54ms/step
# True
# [(360, 170) (412, 222)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(533, 202) (569, 238)]
# True
# C:\Users\Emam\AppData\Local\Temp\ipykernel_14276\516854339.py:14: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if(img[block.top():block.bottom(),block.left():block.right()] !=[]):
# [(360, 176) (412, 228)]
# (48, 48)
# 1/1 [==============================] - 0s 25ms/step
# True
# [(366, 176) (417, 228)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(363, 163) (425, 225)]
# (48, 48)
# 1/1 [==============================] - 0s 23ms/step
# True
# [(371, 170) (423, 222)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(370, 163) (432, 225)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(370, 163) (432, 225)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(370, 163) (432, 225)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(370, 156) (432, 218)]
# (48, 48)
# 1/1 [==============================] - 0s 62ms/step
# [(549, 190) (592, 233)]
# True
# [(370, 163) (432, 225)]
# (48, 48)
# 1/1 [==============================] - 0s 38ms/step
# True
# [(370, 163) (432, 225)]
# (48, 48)
# 1/1 [==============================] - 0s 60ms/step
# True
# [(370, 163) (432, 225)]
# (48, 48)
# 1/1 [==============================] - 0s 62ms/step
# True
# [(361, 155) (436, 229)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(361, 163) (436, 237)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(361, 163) (436, 237)]
# (48, 48)
# 1/1 [==============================] - 0s 45ms/step
# True
# [(361, 163) (436, 237)]
# (48, 48)
# 1/1 [==============================] - 0s 57ms/step
# True
# [(353, 163) (428, 237)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(353, 163) (428, 237)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(353, 163) (428, 237)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(353, 163) (428, 237)]
# (48, 48)
# 1/1 [==============================] - 0s 62ms/step
# True
# [(597, 190) (640, 233)]
# (48, 48)
# 1/1 [==============================] - 0s 62ms/step
# True
# [(345, 163) (419, 237)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(335, 156) (424, 245)]
# (48, 48)
# 1/1 [==============================] - 0s 62ms/step
# True
# True
# [(325, 146) (414, 236)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# True
# True
# [(32, 163) (139, 271)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(306, 128) (414, 235)]
# True
# [(44, 163) (151, 271)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(44, 163) (151, 271)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(305, 146) (394, 236)]
# True
# [(55, 163) (163, 271)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(305, 146) (394, 236)]
# True
# [(55, 163) (163, 271)]
# (48, 48)
# 1/1 [==============================] - 0s 37ms/step
# [(305, 146) (394, 236)]
# True
# [(55, 163) (163, 271)]
# (48, 48)
# 1/1 [==============================] - 0s 38ms/step
# [(294, 128) (402, 235)]
# True
# [(67, 175) (175, 283)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(294, 128) (402, 235)]
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(596, 188) (648, 239)]
# [(294, 128) (402, 235)]
# True
# [(96, 186) (185, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 40ms/step
# [(591, 184) (653, 246)]
# [(294, 128) (402, 235)]
# True
# [(96, 186) (185, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(591, 184) (653, 246)]
# True
# [(106, 186) (195, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 33ms/step
# [(591, 184) (653, 246)]
# True
# [(591, 184) (653, 246)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(116, 186) (205, 275)]
# [(306, 128) (414, 235)]
# True
# [(116, 186) (205, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(591, 184) (653, 246)]
# [(306, 128) (414, 235)]
# True
# [(598, 184) (660, 246)]
# (48, 48)
# 1/1 [==============================] - 0s 29ms/step
# [(129, 188) (204, 262)]
# True
# [(598, 184) (660, 246)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(129, 188) (204, 262)]
# [(318, 116) (426, 223)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(607, 188) (659, 239)]
# [(318, 116) (426, 223)]
# True
# [(605, 184) (667, 246)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(126, 186) (215, 275)]
# [(330, 116) (438, 223)]
# True
# [(613, 188) (665, 239)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(330, 104) (438, 211)]
# [(137, 188) (212, 262)]
# True
# [(612, 184) (674, 246)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(137, 188) (212, 262)]
# [(330, 104) (438, 211)]
# True
# [(135, 186) (225, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(342, 104) (450, 211)]
# [(612, 177) (674, 239)]
# True
# [(135, 186) (225, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(619, 177) (681, 239)]
# [(342, 104) (450, 211)]
# True
# [(135, 186) (225, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(619, 177) (681, 239)]
# [(342, 116) (450, 223)]
# True
# [(135, 186) (225, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(619, 177) (681, 239)]
# [(342, 116) (450, 223)]
# True
# [(135, 186) (225, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(631, 182) (682, 234)]
# [(342, 128) (450, 235)]
# True
# [(135, 186) (225, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(631, 182) (682, 234)]
# [(342, 128) (450, 235)]
# True
# [(135, 186) (225, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(626, 177) (688, 239)]
# [(342, 128) (450, 235)]
# True
# [(135, 186) (225, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(626, 177) (688, 239)]
# True
# [(135, 186) (225, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(626, 184) (688, 246)]
# True
# [(135, 186) (225, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 56ms/step
# [(626, 184) (688, 246)]
# True
# [(137, 188) (212, 262)]
# (48, 48)
# 1/1 [==============================] - 0s 62ms/step
# [(636, 188) (688, 239)]
# True
# [(137, 188) (212, 262)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(636, 188) (688, 239)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(633, 191) (695, 253)]
# [(330, 140) (438, 247)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 38ms/step
# [(330, 140) (438, 247)]
# [(633, 191) (695, 253)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 57ms/step
# [(330, 140) (438, 247)]
# [(633, 191) (695, 253)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(330, 140) (438, 247)]
# [(633, 191) (695, 253)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(330, 140) (438, 247)]
# [(636, 199) (688, 251)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(636, 199) (688, 251)]
# [(325, 125) (454, 254)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(325, 125) (454, 254)]
# [(636, 199) (688, 251)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 63ms/step
# [(325, 125) (454, 254)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 49ms/step
# [(339, 125) (468, 254)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(339, 125) (468, 254)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(339, 125) (468, 254)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(339, 139) (468, 268)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(339, 125) (468, 254)]
# True
# [(126, 186) (215, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 28ms/step
# [(339, 125) (468, 254)]
# True
# [(116, 186) (205, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 28ms/step
# [(354, 125) (483, 254)]
# True
# [(116, 186) (205, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(354, 125) (483, 254)]
# True
# [(116, 186) (205, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(378, 140) (485, 247)]
# True
# [(116, 186) (205, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 44ms/step
# [(368, 125) (497, 254)]
# True
# [(116, 186) (205, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(368, 125) (497, 254)]
# True
# [(106, 186) (195, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 34ms/step
# [(382, 125) (511, 254)]
# True
# [(106, 186) (195, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(106, 186) (195, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(106, 186) (195, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 46ms/step
# True
# [(91, 175) (199, 283)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(96, 186) (185, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(96, 186) (185, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(382, 110) (511, 239)]
# True
# [(86, 176) (175, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(86, 176) (175, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(86, 176) (175, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(382, 125) (511, 254)]
# True
# [(86, 176) (175, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(86, 176) (175, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 40ms/step
# True
# [(86, 176) (175, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 25ms/step
# True
# [(76, 176) (165, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(76, 176) (165, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 40ms/step
# True
# [(76, 176) (165, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 39ms/step
# True
# [(76, 176) (165, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(76, 176) (165, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 61ms/step
# True
# [(76, 176) (165, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 63ms/step
# True
# [(76, 176) (165, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(66, 176) (155, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(66, 176) (155, 265)]
# (48, 48)
# 1/1 [==============================] - 0s 38ms/step
# True
# [(55, 163) (163, 271)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(55, 163) (163, 271)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(55, 163) (163, 271)]
# (48, 48)
# 1/1 [==============================] - 0s 55ms/step
# True
# [(56, 186) (145, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 36ms/step
# True
# [(56, 186) (145, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 40ms/step
# True
# [(330, 140) (438, 247)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(44, 175) (151, 283)]
# True
# [(330, 140) (438, 247)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(44, 175) (151, 283)]
# True
# [(330, 140) (438, 247)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(44, 175) (151, 283)]
# True
# [(330, 152) (438, 259)]
# (48, 48)
# 1/1 [==============================] - 0s 53ms/step
# [(44, 175) (151, 283)]
# True
# [(44, 175) (151, 283)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# [(67, 175) (175, 283)]
# (48, 48)
# 1/1 [==============================] - 0s 23ms/step
# True
# [(67, 175) (175, 283)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(67, 175) (175, 283)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(364, 166) (454, 255)]
# True
# [(67, 175) (175, 283)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# [(364, 166) (454, 255)]
# True
# [(67, 175) (175, 283)]
# (48, 48)
# 1/1 [==============================] - 0s 34ms/step
# [(364, 166) (454, 255)]
# True
# [(76, 186) (165, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(76, 186) (165, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(76, 186) (165, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 29ms/step
# True
# [(76, 186) (165, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 37ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 23ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 46ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(86, 186) (175, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(76, 186) (165, 275)]
# (48, 48)
# 1/1 [==============================] - 0s 39ms/step
# True
# [(305, 126) (394, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 46ms/step
# True
# [(305, 126) (394, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 62ms/step
# True
# [(305, 126) (394, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(305, 126) (394, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(305, 126) (394, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(305, 126) (394, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 43ms/step
# True
# [(294, 116) (402, 223)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# True
# True
# True
# True
# True
# True
# True
# True
# [(295, 126) (384, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(295, 136) (384, 226)]
# (48, 48)
# 1/1 [==============================] - 0s 62ms/step
# True
# [(295, 136) (384, 226)]
# (48, 48)
# 1/1 [==============================] - 0s 62ms/step
# True
# [(285, 136) (374, 226)]
# (48, 48)
# 1/1 [==============================] - 0s 51ms/step
# True
# [(285, 136) (374, 226)]
# (48, 48)
# 1/1 [==============================] - 0s 57ms/step
# True
# [(285, 146) (374, 236)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(285, 146) (374, 236)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(285, 146) (374, 236)]
# (48, 48)
# 1/1 [==============================] - 0s 49ms/step
# True
# [(285, 146) (374, 236)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(285, 146) (374, 236)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# True
# [(285, 136) (374, 226)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(285, 136) (374, 226)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(285, 136) (374, 226)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 39ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 33ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 26ms/step
# True
# [(285, 126) (374, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 31ms/step
# True
# [(295, 126) (384, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# True
# [(295, 126) (384, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 35ms/step
# True
# [(199, 104) (306, 211)]
# (48, 48)
# 1/1 [==============================] - 0s 61ms/step
# [(474, 116) (563, 206)]
# True
# [(474, 116) (563, 206)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(199, 104) (306, 211)]
# True
# [(474, 116) (563, 206)]
# (48, 48)
# 1/1 [==============================] - 0s 62ms/step
# [(187, 104) (294, 211)]
# True
# [(474, 116) (563, 206)]
# (48, 48)
# 1/1 [==============================] - 0s 41ms/step
# [(187, 104) (294, 211)]
# True
# [(464, 116) (554, 206)]
# (48, 48)
# 1/1 [==============================] - 0s 70ms/step
# [(195, 106) (285, 196)]
# True
# [(464, 116) (554, 206)]
# (48, 48)
# 1/1 [==============================] - 0s 33ms/step
# [(187, 104) (294, 211)]
# True
# [(464, 116) (554, 206)]
# (48, 48)
# 1/1 [==============================] - 0s 60ms/step
# [(195, 106) (285, 196)]
# True
# [(464, 126) (554, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 57ms/step
# [(187, 104) (294, 211)]
# True
# [(464, 126) (554, 216)]
# (48, 48)
# 1/1 [==============================] - 0s 47ms/step
# [(187, 104) (294, 211)]

# %%
import cv2
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
#from keras.preprocessing.image import ImageDataGenerator, load_img
import keras as k
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, InceptionResNetV2
from keras import regularizers
from keras.utils import plot_model
from keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
import datetime
labels={ 0:'angry',
 1:'disgust',
 2:'fear',
 3:'happy',
 4:'neutral',
 5:'sad',
6 :'surprise'}
colors={ 0:(0,0,255),
 1:(100,0,100),
 2:(200,50,123),
 3:(0,255,255),
 4:(0,255,0),
 5:(255,255,0),
6 :(255,0,0)}
import numpy as np
def reshape(img):
    img = cv2.resize(img, (48, 48))  # Resize to the input shape of the model
    print(img.shape)
    img = img.reshape( 1,48, 48, 1)
    return img
import numpy as np

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')
model=k.models.load_model('fernet (1).h5')
vid=cv2.VideoCapture(0)# if you would put a vide revmove 0 and put the path
cv2.namedWindow("wind",cv2.WINDOW_NORMAL)
cv2.resizeWindow("wind",1000,1000)
while True:
    rec,frame=vid.read()  
    print(rec)
    if (rec):
        img=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) 
        faces=face_cascade.detectMultiScale(img,scaleFactor=1.3, minNeighbors=5)
        for (x,y,w,h) in faces:
         try: #print(block)
            img=reshape(img[x:x+w+1,y:y+h+1])
            num=np.argmax(model.predict(img),axis=1)[0]
            mode=labels[num]
            cv2.rectangle(frame,(int(x),int(y)),(int(x+w),int(y+h)),colors[num],3)
            cv2.putText(frame,str(mode),(int(x),int(y-15)),cv2.FONT_ITALIC,1,colors[num],3)
            """ 
            img=reshape(img[block.top():block.bottom(),block.left():block.right()])
            num=np.argmax(model.predict(img),axis=1)[0]
            mode=labels[num]
            cv2.rectangle(frame,(int(block.left()),int(block.top())),(int(block.right()),int(block.bottom())),colors[num],3)
            cv2.putText(frame,str(mode),(int(block.left()),int(block.top()-15)),cv2.FONT_ITALIC,1,colors[num],3)"""
            cv2.imshow("wind",frame)
            if (cv2.waitKey(1)==27):
               break
         except:
            cv2.imshow("wind",np.zeros(shape=(1000,1000)))
            if (cv2.waitKey(1)==27):
               break
vid.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       2 model=k.models.load_model('fernet (1).h5')
#       3 vid=cv2.VideoCapture(0)# if you would put a vide revmove 0 and put the path
# ----> 4 vid.open('http://192.168.1.3:8080/video')
#       5 cv2.namedWindow("wind",cv2.WINDOW_NORMAL)
#       6 cv2.resizeWindow("wind",1000,1000)
#
# KeyboardInterrupt:

# %%
from mtcnn import MTCNN
import numpy as np
hog=MTCNN ()
face_cascade = MTCNN ()

model=k.models.load_model('fernet (1).h5')
vid=cv2.VideoCapture(0)# if you would put a vide revmove 0 and put the path
while True:
    rec,frame=vid.read()  
    print(rec)
    if (rec):
        img=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB) 
        faces=face_cascade.detect_faces(img)
        for face in faces:
          #print(block)
          img=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) 

          (x,y,w,h)=face['box']
          if(len(img[x:x+w,y:y+h])>0):
            img=reshape(img[x:x+w,y:y+h])
            num=np.argmax(model.predict(img),axis=1)[0]
            mode=labels[num]
            cv2.rectangle(frame,(int(x),int(y)),(int(x+w),int(y+h)),colors[num],3)
            cv2.putText(frame,str(mode),(int(x),int(y-15)),cv2.FONT_ITALIC,1,colors[num],3)
            """ 
            img=reshape(img[block.top():block.bottom(),block.left():block.right()])
            num=np.argmax(model.predict(img),axis=1)[0]
            mode=labels[num]
            cv2.rectangle(frame,(int(block.left()),int(block.top())),(int(block.right()),int(block.bottom())),colors[num],3)
            cv2.putText(frame,str(mode),(int(block.left()),int(block.top()-15)),cv2.FONT_ITALIC,1,colors[num],3)"""
        cv2.imshow("wind",frame)
        if (cv2.waitKey(1)==27):
            break
vid.release()
cv2.destroyAllWindows()

# %%
! pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ---------------------------------------- 2.3/2.3 MB 370.2 kB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.1.0 in d:\anaconda\lib\site-packages (from mtcnn) (4.7.0.72)
# Requirement already satisfied: keras>=2.0.0 in d:\anaconda\lib\site-packages (from mtcnn) (2.11.0)
# Requirement already satisfied: numpy>=1.17.3 in d:\anaconda\lib\site-packages (from opencv-python>=4.1.0->mtcnn) (1.22.4)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
